# %% [markdown]
# ## Create PyTorch Dataset

# %%
# !pip install -U bitsandbytes

# %% [markdown]
# # !!RESTART AND CLEAR CELL OUTPUTS AFTER UPDATING bitstandbytes

# %%
from skimage import io
import numpy as np
image = io.imread('/kaggle/input/rocov2/ROCOv2/train_images/train/ROCOv2_2023_train_000001.jpg')  # Replace with actual path
print(image.shape)  # Should show (height, width, channels)
# Out:
# (748, 682, 3)

# %%
import os
from PIL import Image
import torch
from torch.utils.data import Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torchvision import transforms
from skimage import io

import torch
from torch.utils.data import DataLoader
from transformers import Blip2ForConditionalGeneration
from torch.optim import AdamW
from tqdm import tqdm
from torchmetrics.text.rouge import ROUGEScore
from torchmetrics.text.bleu import BLEUScore
# from torchmetrics.text.meteor import METEORScore
# from torchmetrics.text.cider import CIDERScore
import os


class ROCODataset(Dataset):
    def __init__(
        self,
        root_dir: str,
        train: bool = False,
        valid: bool = False,
        test: bool = False,
        transform=None
    ):
        self.root_dir = root_dir
        self.transform = transform
        self.train = train
        self.valid = valid
        self.test = test

        self.train_dir = os.path.join(root_dir, 'train_images/train')
        self.val_dir = os.path.join(root_dir, 'valid_images/valid')
        self.test_dir = os.path.join(root_dir, 'test_images/test')

        self.captions = {}
        caption_files = {
            'train': f'{root_dir}/train_captions.csv',
            'valid': f'{root_dir}/valid_captions.csv',
            'test': f'{root_dir}/test_captions.csv'
        }

        for caption in caption_files:
            df = pd.read_csv(caption_files[caption])
            self.captions[caption] = df.set_index('ID').to_dict()['Caption']

        df = pd.read_csv(f'{root_dir}/cui_mapping.csv')
        self.cui_mapping = df.set_index('CUI').to_dict()['Canonical name']

        self.train_len = len(self.captions['train'])
        self.valid_len = len(self.captions['valid'])
        self.test_len = len(self.captions['test'])

    def __len__(self):
        length = 0
        if self.train:
            length += self.train_len
        if self.valid:
            length += self.valid_len
        if self.test:
            length += self.test_len
        return length

    def __getitem__(self, idx) -> dict:
        file_name = ''
        image_loc = ''
        caption = ''

        if self.train:
            file_name = list(self.captions['train'].keys())[idx]
            caption = self.captions['train'][file_name]
            image_loc = os.path.join(self.root_dir, 'train_images/train', f'{file_name}.jpg')
        elif self.valid:
            file_name = list(self.captions['valid'].keys())[idx]
            caption = self.captions['valid'][file_name]
            image_loc = os.path.join(self.root_dir, 'valid_images/valid', f'{file_name}.jpg')
        elif self.test:
            file_name = list(self.captions['test'].keys())[idx]
            caption = self.captions['test'][file_name]
            image_loc = os.path.join(self.root_dir, 'test_images/test', f'{file_name}.jpg')

        img = io.imread(image_loc)

        if self.transform:
            img = self.transform(img)

        return {'image': img, 'text': caption}


# # Define a transform to resize images to 256x256 pixels
# data_transform = transforms.Compose([
#     transforms.ToPILImage(),  # Convert numpy array to PIL image
#     transforms.Resize((224, 224)),  # Resize the image to 256x256 pixels
#     transforms.ToTensor(),  # Convert PIL image to tensor
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ])

root_dir = "/kaggle/input/rocov2/ROCOv2"
train_data = ROCODataset(root_dir, train=True)
valid_data = ROCODataset(root_dir, valid=True)
test_data = ROCODataset(root_dir, test=True)
# Out:
# 2025-07-05 11:44:21.081449: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751715861.305001      88 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751715861.367623      88 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from torch.utils.data import Dataset, DataLoader

"""class ImageCaptioningDataset(Dataset):
    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]
        encoding = self.processor(images=item["image"], padding="max_length", return_tensors="pt")
        # remove batch dimension
        encoding = {k: v.squeeze() for k, v in encoding.items()}
        encoding["text"] = item["text"]
        return encoding"""
from PIL import Image
import numpy as np

class ImageCaptioningDataset(Dataset):
    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]
        image = item["image"]

        # NumPy array ise PIL image'e çevir
        if isinstance(image, np.ndarray):
            image = Image.fromarray(image)

        # Eğer grayscale ya da RGBA ise, RGB'ye çevir
        if image.mode != "RGB":
            image = image.convert("RGB")

        # Process image (not text yet)
        encoding = self.processor(images=image, padding="max_length", return_tensors="pt")
        encoding = {k: v.squeeze() for k, v in encoding.items()}
        encoding["text"] = item["text"]
        return encoding


def collate_fn(batch):
    # pad the input_ids and attention_mask
    processed_batch = {}
    for key in batch[0].keys():
        if key != "text":
            processed_batch[key] = torch.stack([example[key] for example in batch])
        else:
            text_inputs = processor.tokenizer(
                [example["text"] for example in batch], padding=True, return_tensors="pt"
            )
            processed_batch["input_ids"] = text_inputs["input_ids"]
            processed_batch["attention_mask"] = text_inputs["attention_mask"]
    return processed_batch

# %% [markdown]
# ## Load model and processor

# %%
from transformers import AutoProcessor, Blip2ForConditionalGeneration, BitsAndBytesConfig

quantization_config = BitsAndBytesConfig(load_in_8bit=True,
                                         llm_int8_threshold=200.0)

processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-6.7b")

model = Blip2ForConditionalGeneration.from_pretrained(
    "Salesforce/blip2-opt-6.7b",
    #device_map="auto",
    device_map={"": 0},
    torch_dtype=torch.float32,
    quantization_config=quantization_config
)
# Out:
# processor_config.json:   0%|          | 0.00/68.0 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/882 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/987 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/9.93G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/9.93G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/9.80G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]

# %%
train_dataset = ImageCaptioningDataset(train_data, processor)
test_dataset = ImageCaptioningDataset(test_data, processor)
valid_dataset = ImageCaptioningDataset(valid_data, processor)

train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=3, collate_fn=collate_fn)
test_dataloader = DataLoader(test_dataset, shuffle=True, batch_size=3, collate_fn=collate_fn)
valid_dataloader = DataLoader(valid_dataset, shuffle=True, batch_size=3, collate_fn=collate_fn)

# %%
import torch
import gc

def clear_gpu_memory():

    # Python tarafında çöp topla
    gc.collect()

    # PyTorch’un rezerve ettiği kullanılmayan belleği serbest bırak
    torch.cuda.empty_cache()

    # PyTorch’un GPU memory allocator’ını resetle
    torch.cuda.ipc_collect()

for i in range(50):    
    clear_gpu_memory()

# %%
from peft import LoraConfig, get_peft_model

# Let's define the LoraConfig
config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    target_modules=["q_proj", "k_proj"]
)

model = get_peft_model(model, config)
model.print_trainable_parameters()
# Out:
# trainable params: 8,388,608 || all params: 7,761,257,984 || trainable%: 0.1081

# %% [markdown]
# # SU ANLIK GEREKSIZ

# %%
# load weights from a epoch
fine_tuned_weights = torch.load("saved_models_BIIG2/model_epoch_1.pth")
model.load_state_dict(fine_tuned_weights)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_88/1141456990.py in <cell line: 0>()
#       1 # load weights from a epoch
# ----> 2 fine_tuned_weights = torch.load("saved_models_BIIG2/model_epoch_1.pth")
#       3 model.load_state_dict(fine_tuned_weights)
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1423         pickle_load_args["encoding"] = "utf-8"
#    1424
# -> 1425     with _open_file_like(f, "rb") as opened_file:
#    1426         if _is_zipfile(opened_file):
#    1427             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     749 def _open_file_like(name_or_buffer, mode):
#     750     if _is_path(name_or_buffer):
# --> 751         return _open_file(name_or_buffer, mode)
#     752     else:
#     753         if "w" in mode:
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     730 class _open_file(_opener):
#     731     def __init__(self, name, mode):
# --> 732         super().__init__(open(name, mode))
#     733
#     734     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'saved_models_BIIG2/model_epoch_1.pth'

# %% [markdown]
# ## Train the model

# %% [markdown]
# model trained with 100 images

# %%
for i in range(50):    
    clear_gpu_memory()

# %%
import torch
from torch.utils.data import DataLoader, Subset
from tqdm import tqdm
import os
import gc

# GPU temizleme fonksiyonu
def clear_gpu_memory():
    torch.cuda.empty_cache()
    gc.collect()

# Cihaz ayarı
device = torch.device("cuda:0")
model = model.to(device)

# Dataset alt kümesi
train_subset = Subset(train_dataset, list(range(100)))
train_dataloader = DataLoader(train_subset, batch_size=2, shuffle=True, collate_fn=collate_fn)

# Optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

# Modeli eğitim moduna al
model.train()

# Kayıt dizini
save_dir = "saved_models_BIIG"
os.makedirs(save_dir, exist_ok=True)
clear_gpu_memory()
# Eğitim döngüsü
for epoch in range(2):  
    print(f"Epoch: {epoch}")
    epoch_iterator = tqdm(train_dataloader, desc="Iteration")

    for batch in epoch_iterator:
        input_ids = batch["input_ids"].to(device)
        pixel_values = batch["pixel_values"].to(device)

        optimizer.zero_grad()
        outputs = model(input_ids=input_ids, pixel_values=pixel_values, labels=input_ids)
        loss = outputs.loss

        epoch_iterator.set_postfix(loss=loss.item())

        loss.backward()
        optimizer.step()

    torch.save(model.state_dict(), os.path.join(save_dir, f"model_epoch_{epoch}.pth"))
# Out:
# Epoch: 0
# Iteration:   0%|          | 0/50 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:   2%|▏         | 1/50 [00:00<00:40,  1.21it/s, loss=10.6]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:   4%|▍         | 2/50 [00:01<00:48,  1.01s/it, loss=8.75]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:   6%|▌         | 3/50 [00:03<00:51,  1.09s/it, loss=9.6] /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:   8%|▊         | 4/50 [00:04<00:54,  1.18s/it, loss=7.42]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  10%|█         | 5/50 [00:05<00:53,  1.19s/it, loss=6.91]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  12%|█▏        | 6/50 [00:06<00:52,  1.19s/it, loss=9.76]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  14%|█▍        | 7/50 [00:07<00:49,  1.15s/it, loss=8.05]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  16%|█▌        | 8/50 [00:08<00:45,  1.09s/it, loss=10.9]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  18%|█▊        | 9/50 [00:09<00:44,  1.08s/it, loss=11.2]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  20%|██        | 10/50 [00:10<00:42,  1.07s/it, loss=7.01]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  22%|██▏       | 11/50 [00:12<00:42,  1.08s/it, loss=8.47]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  24%|██▍       | 12/50 [00:13<00:40,  1.07s/it, loss=9.02]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  26%|██▌       | 13/50 [00:14<00:39,  1.08s/it, loss=9.57]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  28%|██▊       | 14/50 [00:15<00:39,  1.09s/it, loss=10.7]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  30%|███       | 15/50 [00:16<00:37,  1.08s/it, loss=8.21]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  32%|███▏      | 16/50 [00:17<00:36,  1.07s/it, loss=10.7]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  34%|███▍      | 17/50 [00:18<00:36,  1.09s/it, loss=8.93]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  36%|███▌      | 18/50 [00:19<00:34,  1.09s/it, loss=9.67]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  38%|███▊      | 19/50 [00:20<00:32,  1.06s/it, loss=8.44]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  40%|████      | 20/50 [00:21<00:32,  1.07s/it, loss=8.79]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  42%|████▏     | 21/50 [00:22<00:30,  1.05s/it, loss=8.64]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  44%|████▍     | 22/50 [00:23<00:29,  1.04s/it, loss=9.22]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  46%|████▌     | 23/50 [00:24<00:27,  1.01s/it, loss=7.71]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  48%|████▊     | 24/50 [00:25<00:25,  1.01it/s, loss=9.27]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  50%|█████     | 25/50 [00:26<00:23,  1.05it/s, loss=9.24]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  52%|█████▏    | 26/50 [00:27<00:24,  1.02s/it, loss=10.5]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  54%|█████▍    | 27/50 [00:28<00:24,  1.07s/it, loss=9.59]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  56%|█████▌    | 28/50 [00:29<00:23,  1.07s/it, loss=9.82]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  58%|█████▊    | 29/50 [00:30<00:21,  1.03s/it, loss=8.81]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  60%|██████    | 30/50 [00:31<00:20,  1.02s/it, loss=7.87]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  62%|██████▏   | 31/50 [00:32<00:19,  1.01s/it, loss=10.3]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  64%|██████▍   | 32/50 [00:34<00:20,  1.16s/it, loss=9.5] /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  66%|██████▌   | 33/50 [00:35<00:20,  1.22s/it, loss=8.9]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  68%|██████▊   | 34/50 [00:36<00:17,  1.12s/it, loss=9.52]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  70%|███████   | 35/50 [00:37<00:16,  1.07s/it, loss=9.09]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  72%|███████▏  | 36/50 [00:38<00:15,  1.09s/it, loss=9.77]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  74%|███████▍  | 37/50 [00:40<00:15,  1.18s/it, loss=9.29]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  76%|███████▌  | 38/50 [00:41<00:14,  1.20s/it, loss=9.36]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  78%|███████▊  | 39/50 [00:42<00:12,  1.15s/it, loss=9.35]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  80%|████████  | 40/50 [00:43<00:10,  1.09s/it, loss=9.92]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  82%|████████▏ | 41/50 [00:44<00:10,  1.15s/it, loss=6.21]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  84%|████████▍ | 42/50 [00:45<00:09,  1.16s/it, loss=8.53]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  86%|████████▌ | 43/50 [00:46<00:08,  1.16s/it, loss=7.66]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  88%|████████▊ | 44/50 [00:48<00:06,  1.12s/it, loss=9.09]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  90%|█████████ | 45/50 [00:48<00:05,  1.07s/it, loss=9.06]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  92%|█████████▏| 46/50 [00:50<00:04,  1.08s/it, loss=6.46]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  94%|█████████▍| 47/50 [00:51<00:03,  1.09s/it, loss=9.9] /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  96%|█████████▌| 48/50 [00:52<00:02,  1.07s/it, loss=8.49]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  98%|█████████▊| 49/50 [00:53<00:01,  1.02s/it, loss=9.57]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration: 100%|██████████| 50/50 [00:54<00:00,  1.08s/it, loss=9.26]
# Epoch: 1
# Iteration:   0%|          | 0/50 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:   2%|▏         | 1/50 [00:00<00:33,  1.46it/s, loss=8.3]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:   4%|▍         | 2/50 [00:01<00:41,  1.15it/s, loss=9.95]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:   6%|▌         | 3/50 [00:02<00:46,  1.02it/s, loss=9.47]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:   8%|▊         | 4/50 [00:04<00:50,  1.10s/it, loss=8.17]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  10%|█         | 5/50 [00:05<00:50,  1.12s/it, loss=9.65]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  12%|█▏        | 6/50 [00:06<00:48,  1.10s/it, loss=10.5]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  14%|█▍        | 7/50 [00:07<00:45,  1.06s/it, loss=9.33]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  16%|█▌        | 8/50 [00:09<00:56,  1.34s/it, loss=9.51]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  18%|█▊        | 9/50 [00:10<00:49,  1.21s/it, loss=9.86]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  20%|██        | 10/50 [00:11<00:47,  1.19s/it, loss=5.9]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  22%|██▏       | 11/50 [00:12<00:44,  1.15s/it, loss=9.27]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  24%|██▍       | 12/50 [00:13<00:42,  1.12s/it, loss=6.81]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  26%|██▌       | 13/50 [00:14<00:39,  1.08s/it, loss=8.32]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  28%|██▊       | 14/50 [00:15<00:38,  1.07s/it, loss=9.41]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  30%|███       | 15/50 [00:16<00:35,  1.03s/it, loss=7.94]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  32%|███▏      | 16/50 [00:17<00:34,  1.03s/it, loss=8.91]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  34%|███▍      | 17/50 [00:18<00:35,  1.07s/it, loss=9.28]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  36%|███▌      | 18/50 [00:19<00:33,  1.06s/it, loss=7.14]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  38%|███▊      | 19/50 [00:20<00:31,  1.02s/it, loss=8.55]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  40%|████      | 20/50 [00:21<00:29,  1.01it/s, loss=8.44]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  42%|████▏     | 21/50 [00:22<00:28,  1.01it/s, loss=6.38]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  44%|████▍     | 22/50 [00:23<00:28,  1.01s/it, loss=8.09]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  46%|████▌     | 23/50 [00:24<00:27,  1.00s/it, loss=9.51]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  48%|████▊     | 24/50 [00:25<00:28,  1.09s/it, loss=8.62]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  50%|█████     | 25/50 [00:26<00:27,  1.10s/it, loss=8.49]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  52%|█████▏    | 26/50 [00:27<00:24,  1.03s/it, loss=10.6]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  54%|█████▍    | 27/50 [00:28<00:22,  1.00it/s, loss=7.29]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  56%|█████▌    | 28/50 [00:30<00:25,  1.17s/it, loss=10.6]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  58%|█████▊    | 29/50 [00:31<00:27,  1.33s/it, loss=8.92]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  60%|██████    | 30/50 [00:33<00:26,  1.31s/it, loss=7.64]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  62%|██████▏   | 31/50 [00:34<00:23,  1.21s/it, loss=7.4] /usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  64%|██████▍   | 32/50 [00:35<00:20,  1.16s/it, loss=7.86]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  66%|██████▌   | 33/50 [00:36<00:20,  1.21s/it, loss=10.5]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  68%|██████▊   | 34/50 [00:38<00:20,  1.29s/it, loss=7.48]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  70%|███████   | 35/50 [00:39<00:18,  1.25s/it, loss=9.08]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  72%|███████▏  | 36/50 [00:40<00:16,  1.16s/it, loss=8.64]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  74%|███████▍  | 37/50 [00:41<00:14,  1.11s/it, loss=9.76]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  76%|███████▌  | 38/50 [00:42<00:13,  1.09s/it, loss=9.61]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  78%|███████▊  | 39/50 [00:43<00:12,  1.13s/it, loss=8.36]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  80%|████████  | 40/50 [00:44<00:11,  1.15s/it, loss=7.28]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  82%|████████▏ | 41/50 [00:45<00:10,  1.11s/it, loss=9.46]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  84%|████████▍ | 42/50 [00:46<00:08,  1.09s/it, loss=10.3]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  86%|████████▌ | 43/50 [00:47<00:07,  1.05s/it, loss=6.66]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  88%|████████▊ | 44/50 [00:48<00:06,  1.07s/it, loss=7.59]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  90%|█████████ | 45/50 [00:49<00:05,  1.08s/it, loss=9.04]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  92%|█████████▏| 46/50 [00:50<00:04,  1.08s/it, loss=8.68]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  94%|█████████▍| 47/50 [00:51<00:03,  1.07s/it, loss=8.44]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  96%|█████████▌| 48/50 [00:52<00:02,  1.04s/it, loss=8.23]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration:  98%|█████████▊| 49/50 [00:53<00:01,  1.04s/it, loss=9.66]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Iteration: 100%|██████████| 50/50 [00:54<00:00,  1.10s/it, loss=10]

# %% [markdown]
# ### part 1

# %%
import torch
from tqdm import tqdm
import os

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

# Determine device
device = "cuda" if torch.cuda.is_available() else "cpu"

# Set the model to training mode
model.train()

# Directory to save models
save_dir = "saved_models_BIIG"
os.makedirs(save_dir, exist_ok=True)

# Training loop with progress bar and model saving
for epoch in range(5):
    clear_gpu_memory()

    print(f"Epoch: {epoch}")
    epoch_iterator = tqdm(train_dataloader, desc="Iteration")

    for idx, batch in enumerate(epoch_iterator):
        clear_gpu_memory()
        input_ids = batch["input_ids"].to(device)
        pixel_values = batch["pixel_values"].to(device)  # Removed float16

        optimizer.zero_grad()

        outputs = model(input_ids=input_ids, pixel_values=pixel_values, labels=input_ids)
        loss = outputs.loss

        epoch_iterator.set_postfix(loss=loss.item())

        loss.backward()
        optimizer.step()

    torch.save(model.state_dict(), os.path.join(save_dir, f"model_epoch_{epoch}.pth"))

# %% [markdown]
# ### part       2

# %%
import torch
from tqdm import tqdm
import os

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

# Determine device
device = "cuda" if torch.cuda.is_available() else "cpu"

# Set the model to training mode
model.train()

# Directory to save models
save_dir = "saved_models_BIIG2"
os.makedirs(save_dir, exist_ok=True)

# Training loop with progress bar and model saving
for epoch in range(2):
    print(f"Epoch: {epoch}")
    epoch_iterator = tqdm(train_dataloader, desc="Iteration")
    
    for idx, batch in enumerate(epoch_iterator):
        input_ids = batch["input_ids"].to(device)
        pixel_values = batch["pixel_values"].to(device, torch.float16)
        
        optimizer.zero_grad()
        
        outputs = model(input_ids=input_ids, pixel_values=pixel_values, labels=input_ids)
        loss = outputs.loss
        
        epoch_iterator.set_postfix(loss=loss.item())
        
        loss.backward()
        optimizer.step()
    
    # Save model after each epoch
    torch.save(model.state_dict(), os.path.join(save_dir, f"model_epoch_{epoch}.pth"))

# %% [markdown]
# # ME

# %%
model.eval()
def img_to_cap(img,model,processor,device):
    inputs = processor(images=image, return_tensors="pt").to(device, torch.float16)
    pixel_values = inputs.pixel_values

    generated_ids = model.generate(pixel_values=pixel_values, max_length=25)
    generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    return generated_caption

# %%
predictions = []
references = []

# Initialize counters and batch size
batch_size = 100
file_index = 0

# Process each item in the test data
for idx in tqdm(range(len(test_data))):
    # Get the image and caption
    image = valid_data[idx]['image']
    caption = valid_data[idx]['text']
    
    # Generate the prediction
    gen_ = img_to_cap(image, model, processor, 'cuda')
    
    # Append the prediction and reference to lists
    predictions.append(gen_)
    references.append([caption])
    
    # Every 100 examples, save the results to a text file
    if (idx + 1) % batch_size == 0 or (idx + 1) == len(test_data):
        # Define the file names for saving
        pred_filename = f'predictions_batch_{file_index}.txt'
        ref_filename = f'references_batch_{file_index}.txt'
        
        # Save predictions
        with open(pred_filename, 'w') as pred_file:
            for pred in predictions:
                pred_file.write(pred + '\n')
        
        # Save references
        with open(ref_filename, 'w') as ref_file:
            for ref_list in references:
                ref_file.write('\t'.join(ref_list) + '\n')
        
        
        # Increment file index
        file_index += 1

print("Processing and saving completed.")

# for idx in tqdm(range(len(test_data))):
#     image = valid_data[idx]['image'].to(device)
#     caption = valid_data[idx]['text'].to(device)
#     gen_ = img_to_cap(image,model, processor, 'cuda')

#     predictions.append(gen_)
#     references.append([caption])
# Out:
#   0%|          | 0/9927 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 1/9927 [00:02<5:37:30,  2.04s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 2/9927 [00:03<5:06:09,  1.85s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 3/9927 [00:04<3:39:45,  1.33s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 4/9927 [00:05<3:38:19,  1.32s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 5/9927 [00:07<3:58:35,  1.44s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 6/9927 [00:08<3:46:01,  1.37s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 7/9927 [00:10<4:04:30,  1.48s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 8/9927 [00:11<3:58:59,  1.45s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 9/9927 [00:14<4:50:17,  1.76s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 10/9927 [00:15<4:34:24,  1.66s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 11/9927 [00:16<3:59:20,  1.45s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 12/9927 [00:19<5:04:23,  1.84s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 13/9927 [00:21<4:57:56,  1.80s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 14/9927 [00:22<4:44:05,  1.72s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 15/9927 [00:23<4:23:44,  1.60s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 16/9927 [00:24<3:56:24,  1.43s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 17/9927 [00:26<3:38:33,  1.32s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 18/9927 [00:27<3:33:46,  1.29s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 19/9927 [00:29<4:02:20,  1.47s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 20/9927 [00:30<4:01:06,  1.46s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 21/9927 [00:31<3:29:33,  1.27s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 22/9927 [00:33<4:04:07,  1.48s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 23/9927 [00:34<3:55:38,  1.43s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 24/9927 [00:37<4:59:19,  1.81s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 25/9927 [00:39<4:57:31,  1.80s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 26/9927 [00:40<4:37:29,  1.68s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 27/9927 [00:42<4:42:04,  1.71s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 28/9927 [00:44<4:54:10,  1.78s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 29/9927 [00:45<4:39:31,  1.69s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 30/9927 [00:47<4:30:03,  1.64s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 31/9927 [00:48<3:52:34,  1.41s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 32/9927 [00:50<4:36:29,  1.68s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 33/9927 [00:52<4:31:22,  1.65s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 34/9927 [00:53<4:28:44,  1.63s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 35/9927 [00:54<4:15:35,  1.55s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 36/9927 [00:56<3:53:18,  1.42s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 37/9927 [00:58<4:40:21,  1.70s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 38/9927 [00:59<4:29:23,  1.63s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 39/9927 [01:01<4:09:44,  1.52s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 40/9927 [01:02<3:59:52,  1.46s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 41/9927 [01:03<3:49:49,  1.39s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 42/9927 [01:05<3:55:41,  1.43s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 43/9927 [01:06<3:39:24,  1.33s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 44/9927 [01:07<3:34:08,  1.30s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 45/9927 [01:10<4:47:14,  1.74s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 46/9927 [01:11<4:21:12,  1.59s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 47/9927 [01:12<3:56:33,  1.44s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 48/9927 [01:13<3:45:48,  1.37s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 49/9927 [01:15<3:54:45,  1.43s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 50/9927 [01:17<4:09:45,  1.52s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 51/9927 [01:17<3:35:36,  1.31s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 52/9927 [01:19<3:30:29,  1.28s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 53/9927 [01:20<3:34:55,  1.31s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 54/9927 [01:22<3:47:55,  1.39s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 55/9927 [01:23<3:32:30,  1.29s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 56/9927 [01:24<3:51:39,  1.41s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 57/9927 [01:26<3:47:14,  1.38s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 58/9927 [01:27<3:58:10,  1.45s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 59/9927 [01:29<3:54:01,  1.42s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 60/9927 [01:30<3:49:51,  1.40s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 61/9927 [01:31<3:52:42,  1.42s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 62/9927 [01:34<4:32:23,  1.66s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 63/9927 [01:36<4:49:43,  1.76s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 64/9927 [01:38<5:02:05,  1.84s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 65/9927 [01:40<5:07:08,  1.87s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 66/9927 [01:41<4:28:13,  1.63s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 67/9927 [01:43<4:43:49,  1.73s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 68/9927 [01:44<4:43:40,  1.73s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 69/9927 [01:47<5:35:27,  2.04s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 70/9927 [01:50<6:10:43,  2.26s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 71/9927 [01:51<5:12:19,  1.90s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 72/9927 [01:52<4:39:21,  1.70s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 73/9927 [01:54<4:28:45,  1.64s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 74/9927 [01:55<3:54:18,  1.43s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 75/9927 [01:56<3:36:14,  1.32s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 76/9927 [01:57<3:25:12,  1.25s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 77/9927 [01:58<3:29:58,  1.28s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 78/9927 [02:00<4:00:51,  1.47s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 79/9927 [02:02<4:11:25,  1.53s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 80/9927 [02:03<3:47:49,  1.39s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 81/9927 [02:05<4:52:03,  1.78s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 82/9927 [02:07<4:59:57,  1.83s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 83/9927 [02:08<4:14:47,  1.55s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 84/9927 [02:10<3:59:25,  1.46s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 85/9927 [02:12<4:36:28,  1.69s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 86/9927 [02:14<5:08:32,  1.88s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 87/9927 [02:16<4:47:34,  1.75s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 88/9927 [02:17<4:22:24,  1.60s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 89/9927 [02:18<3:47:03,  1.38s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 90/9927 [02:19<4:03:34,  1.49s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 91/9927 [02:21<4:26:47,  1.63s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 92/9927 [02:23<4:37:08,  1.69s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 93/9927 [02:25<4:36:47,  1.69s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 94/9927 [02:28<5:27:49,  2.00s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 95/9927 [02:29<4:43:54,  1.73s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 96/9927 [02:30<4:05:35,  1.50s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 97/9927 [02:32<4:22:45,  1.60s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 98/9927 [02:34<4:39:52,  1.71s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 99/9927 [02:35<4:08:41,  1.52s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   1%|          | 99/9927 [02:36<4:18:34,  1.58s/it]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_88/2149467372.py in <cell line: 0>()
#      26
#      27         # Save predictions
# ---> 28         with open(pred_filename, 'w') as pred_file:
#      29             for pred in predictions:
#      30                 pred_file.write(pred + '\n')
#
# OSError: [Errno 28] No space left on device

# %%
import json

def process_predictions(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    predictions = [{"image_id": str(index), "caption": line.strip()} for index, line in enumerate(lines)]
    
    with open('captions_example.json', 'w') as json_file:
        json.dump(predictions, json_file, indent=4)

def process_references(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    images = [{"id": str(index)} for index in range(len(lines))]
    annotations = [{"image_id": str(index), "id": str(index), "caption": line.strip()} for index, line in enumerate(lines)]
    
    references = {
        "images": images,
        "annotations": annotations
    }
    
    with open('references_example.json', 'w') as json_file:
        json.dump(references, json_file, indent=4)

# Paths to the text files
predictions_file_path = '/home/CinCin/code/predictions_batch_65.txt'
references_file_path = '/home/CinCin/code/references_batch_65.txt'

# Process the files and create JSON files
process_predictions(predictions_file_path)
process_references(references_file_path)

# %% [markdown]
# zeynep codes

# %%
for i in range(50):    
    clear_gpu_memory()

# %%
from PIL import Image
import numpy as np

def img_to_cap(img, model, processor, device):
    model.eval()

    # Eğer image NumPy array ise ve 3 kanallı değilse, RGB'ye çevir
    if isinstance(img, np.ndarray):
        if img.ndim == 2:  # grayscale
            img = np.stack([img]*3, axis=-1)  # grayscale -> RGB
        img = Image.fromarray(img.astype('uint8')).convert("RGB")

    # Görüntüyü modele verilecek formata getir
    inputs = processor(images=img, return_tensors="pt").to(device)
    
    # Görüntüden caption üret
    with torch.no_grad():
        generated_ids = model.generate(**inputs)
        caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

    return caption

# %%
# Yalnızca ilk 10 görüntüyü işle
num_examples_to_try = 10  # İstersen bunu 5 veya başka bir sayı yapabilirsin

predictions = []
references = []

batch_size = 5  # Küçük tut, her 5 örnekte bir dosya kaydedilecek
file_index = 0

# Sınırlı sayıda veri üzerinde çalış
for idx in tqdm(range(num_examples_to_try)):
    image = valid_data[idx]['image']
    caption = valid_data[idx]['text']
    
    gen_ = img_to_cap(image, model, processor, 'cuda')
    
    predictions.append(gen_)
    references.append([caption])
    
    if (idx + 1) % batch_size == 0 or (idx + 1) == num_examples_to_try:
        pred_filename = f'predictions_batch_{file_index}.txt'
        ref_filename = f'references_batch_{file_index}.txt'
        
        with open(pred_filename, 'w') as pred_file:
            for pred in predictions:
                pred_file.write(pred + '\n')
        
        with open(ref_filename, 'w') as ref_file:
            for ref_list in references:
                ref_file.write('\t'.join(ref_list) + '\n')
        
        file_index += 1

print("Processing and saving completed.")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#  10%|█         | 1/10 [00:01<00:15,  1.72s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#  20%|██        | 2/10 [00:03<00:13,  1.69s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#  30%|███       | 3/10 [00:04<00:08,  1.23s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#  40%|████      | 4/10 [00:05<00:07,  1.31s/it]/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py:185: UserWarning: MatMul8bitLt: inputs will be cast from torch.float32 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#  40%|████      | 4/10 [00:07<00:10,  1.80s/it]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_88/1861864006.py in <cell line: 0>()
#      22         ref_filename = f'references_batch_{file_index}.txt'
#      23
# ---> 24         with open(pred_filename, 'w') as pred_file:
#      25             for pred in predictions:
#      26                 pred_file.write(pred + '\n')
#
# OSError: [Errno 28] No space left on device

# %%
# import pymeteor.pymeteor as pymeteor
# # metoer
# sumup = 0
# for idx in range(len(references)):
#     reference = references[idx][0]

#     meteor_score = pymeteor.meteor(reference, predictions[ref])
#     sumup += meteor_score
# print(sumup/len(references))

# %%
for idx in tqdm(range(len(test_data))):
    # Get the image and caption
    image = valid_data[idx]['image']
    caption = valid_data[idx]['text']
    
    # Generate the prediction
    gen_ = img_to_cap(image, model, processor, 'cuda')

# %%
plt.imshow(valid_data[1]['image'])

image = valid_data[1]['image']
caption = valid_data[1]['text']

# Generate the prediction
gen_ = img_to_cap(image, model, processor, 'cuda')

print('source:\n',caption)
print('gen:\n',gen_)

# %%
idx_ = 20
plt.imshow(valid_data[idx_]['image'])

image = valid_data[idx_]['image']
caption = valid_data[idx_]['text']

# Generate the prediction
gen_ = img_to_cap(image, model, processor, 'cuda')

print('source:\n',caption)
print('gen:\n',gen_)

# %%
idx_ = 180
plt.imshow(valid_data[idx_]['image'])

image = valid_data[idx_]['image']
caption = valid_data[idx_]['text']

# Generate the prediction
gen_ = img_to_cap(image, model, processor, 'cuda')

print('source:\n',caption)
print('gen:\n',gen_)

# %%
idx_ = 499
plt.imshow(valid_data[idx_]['image'])

image = valid_data[idx_]['image']
caption = valid_data[idx_]['text']

# Generate the prediction
gen_ = img_to_cap(image, model, processor, 'cuda')

print('source:\n',caption)
print('gen:\n',gen_)

# %%
! python /home/CinCin/bleu-rouge-meteor-cider-spice-eval4imagecaption/example/main.py

# %% [markdown]
# ## Inference

# %%
import torch
from matplotlib import pyplot as plt

device = "cuda" if torch.cuda.is_available() else "cpu"

fig = plt.figure(figsize=(18, 14))

# prepare image for the model
for i, example in enumerate(test_data):
  image = example["image"]
  inputs = processor(images=image, return_tensors="pt").to(device, torch.float16)
  pixel_values = inputs.pixel_values

  generated_ids = model.generate(pixel_values=pixel_values, max_length=25)
  generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
  fig.add_subplot(2, 3, i+1)
  plt.imshow(image)
  plt.axis("off")
  plt.title(f"Generated caption: {generated_caption}")
